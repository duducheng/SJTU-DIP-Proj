# %%
import PIL.Image
import numpy as np

# %%
pil = PIL.Image.open("imgs/test1.jpg")

# %%
np.array(pil.convert('LA'))
# Out:
# array([[[ 52, 255],
#         [ 47, 255],
#         [ 54, 255],
#         ...,
#         [103, 255],
#         [104, 255],
#         [104, 255]],
#
#        [[ 50, 255],
#         [ 47, 255],
#         [ 54, 255],
#         ...,
#         [104, 255],
#         [104, 255],
#         [104, 255]],
#
#        [[ 54, 255],
#         [ 49, 255],
#         [ 50, 255],
#         ...,
#         [104, 255],
#         [105, 255],
#         [106, 255]],
#
#        ...,
#        [[155, 255],
#         [155, 255],
#         [154, 255],
#         ...,
#         [151, 255],
#         [152, 255],
#         [148, 255]],
#
#        [[156, 255],
#         [157, 255],
#         [155, 255],
#         ...,
#         [160, 255],
#         [150, 255],
#         [121, 255]],
#
#        [[156, 255],
#         [155, 255],
#         [155, 255],
#         ...,
#         [158, 255],
#         [155, 255],
#         [145, 255]]], dtype=uint8)

# %%
arr = np.array(pil)

# %%
arr.shape
# Out:
# (3024, 4032, 3)

# %%
PIL.Image.fromarray(((arr>67)*255).astype(np.uint8))
# Out:
# <PIL.Image.Image image mode=RGB size=4032x3024 at 0x7FDEC44485F8>
